# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import csv
from sqlalchemy import create_engine

# %%
#Choose desired format
response_format = "csv"

# %%
#import file
election_file = "1980-2014 November_General_Election_Turnout_Rates.csv"
election_df = pd.read_csv(election_file)
election_df.head()
# Out:
#    Year  ICPSR State Code  Alphanumeric State Code          State  \
# 0  2014                 0                        0  United States
# 1  2014                41                        1        Alabama
# 2  2014                81                        2         Alaska
# 3  2014                61                        3        Arizona
# 4  2014                42                        4       Arkansas
#
#   VEP Total Ballots Counted VEP Highest Office VAP Highest Office  \
# 0                    36.70%             36.00%             33.20%
# 1                    33.20%             32.90%             31.50%
# 2                    54.80%             54.20%             51.00%
# 3                    34.10%             33.40%             29.50%
# 4                    40.30%             40.10%             37.50%
#
#   Total Ballots Counted Highest Office Voting-Eligible Population (VEP)  \
# 0            83,262,122     81,687,059                      227,157,964
# ...

# %%
# Create a filter DF with only needed columns 
election_cols = ["Year", "State", "VEP Total Ballots Counted", "VEP Highest Office", "VAP Highest Office", "Total Ballots Counted", "Highest Office", "Voting-Eligible Population (VEP)", "Voting-Age Population (VAP)", "Overseas Eligible"]
election_df2 = election_df[election_cols].copy()
election_df2.head(20)
# Out:
#     Year                 State VEP Total Ballots Counted VEP Highest Office  \
# 0   2014         United States                    36.70%             36.00%
# 1   2014               Alabama                    33.20%             32.90%
# 2   2014                Alaska                    54.80%             54.20%
# 3   2014               Arizona                    34.10%             33.40%
# 4   2014              Arkansas                    40.30%             40.10%
# 5   2014            California                    30.70%             29.90%
# 6   2014              Colorado                    54.70%             53.70%
# 7   2014           Connecticut                    42.50%             42.30%
# 8   2014              Delaware                    34.90%             34.30%
# 9   2014  District of Columbia                    35.70%             35.30%
# 10  2014               Florida                    43.30%             42.80%
# ...
