# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import csv
from sqlalchemy import create_engine

# %%
#Choose desired format
response_format = "csv"

# %%
#import file
election_file = "1980-2016 November_General_Election_Turnout_Rates.csv"
election_df = pd.read_csv(election_file)
election_df.head()
# Out:
#    Year       State VEP Total Ballots Counted VEP Highest Office  \
# 0  2014     Alabama                    33.20%             32.90%
# 1  2014      Alaska                    54.80%             54.20%
# 2  2014     Arizona                    34.10%             33.40%
# 3  2014    Arkansas                    40.30%             40.10%
# 4  2014  California                    30.70%             29.90%
#
#   VAP Highest Office Total Ballots Counted Highest Office  \
# 0             31.50%             1,191,274      1,180,413
# 1             51.00%               285,431        282,382
# 2             29.50%             1,537,671      1,506,416
# 3             37.50%               852,642        848,592
# 4             24.70%             7,513,972      7,317,581
#
#   Voting-Eligible Population (VEP) Voting-Age Population (VAP)  Unnamed: 9
# 0                        3,588,783                   3,751,844         NaN
# ...

# %%
# Create a filter DF with only needed columns 
election_cols = ["Year", "State", "VEP Total Ballots Counted", "VEP Highest Office", "VAP Highest Office", "Total Ballots Counted", "Highest Office", "Voting-Eligible Population (VEP)", "Voting-Age Population (VAP)"]
election_df2 = election_df[election_cols].copy()
election_df2.head(20)
# Out:
#     Year                 State VEP Total Ballots Counted VEP Highest Office  \
# 0   2014               Alabama                    33.20%             32.90%
# 1   2014                Alaska                    54.80%             54.20%
# 2   2014               Arizona                    34.10%             33.40%
# 3   2014              Arkansas                    40.30%             40.10%
# 4   2014            California                    30.70%             29.90%
# 5   2014              Colorado                    54.70%             53.70%
# 6   2014           Connecticut                    42.50%             42.30%
# 7   2014              Delaware                    34.90%             34.30%
# 8   2014  District of Columbia                    35.70%             35.30%
# 9   2014               Florida                    43.30%             42.80%
# 10  2014               Georgia                    38.60%             38.20%
# ...

# %%
df = election_df2.loc[election_df2['Year']==2016]

# %%
df.head(30)
# Out:
#      Year                 State VEP Total Ballots Counted VEP Highest Office  \
# 918  2016               Alabama                    59.10%             58.80%
# 919  2016                Alaska                    61.50%             61.00%
# 920  2016               Arizona                    56.10%             54.90%
# 921  2016              Arkansas                    53.20%             52.80%
# 922  2016            California                    58.20%             56.50%
# 923  2016              Colorado                    71.90%             70.00%
# 924  2016           Connecticut                    64.90%             63.70%
# 925  2016              Delaware                    64.40%             64.20%
# 926  2016  District of Columbia                    60.70%             60.40%
# 927  2016               Florida                    65.60%             64.50%
# 928  2016               Georgia                    59.80%             59.10%
# ...
